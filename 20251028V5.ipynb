# %% [markdown]
# <a href="https://colab.research.google.com/github/jcvancity2022/Computer-Vision-Project-Overview/blob/main/20251028V5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1> <b>Image Dataset Analysis and Project Development with YOLO </b> </center> </h1>
#
# In this tutorial, we will see how image datasets with different types of tasks such as detection , segmentation etc. look like, and how they are labelled, specifically in YOLO format.
#
# Then, we will download one dataset to explore it and clean it if required.

# %% [markdown]
# ## **Classification**
#
# Image classification is the simplest and involves classifying an entire image into one of a set of predefined classes.
#
# The output of an image classifier is a single class label and a confidence score. Image classification is useful when you need to know only what class an image belongs to and don't need to know where objects of that class are located or what their exact shape is.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418606-adf35c62-2e11-405d-84c6-b84e7d013804.png" width="600">

# %% [markdown]
# Usually each image has a single object in it, which is its class> Following image shows CIFAR10 Dataset.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://datagen.tech/wp-content/uploads/2022/11/image1.png" width="600">

# %% [markdown]
# The dataset should be labelled by arranging them in the following folders heirarchy.
#
#               root/
#               |-- class1/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- class2/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- class3/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- ...
#
# In this folder structure, the root directory contains one subdirectory for each class in the dataset. Each subdirectory is named after the corresponding class and contains all the images for that class.
#
# For example:
#
#               cifar-10-/
#               |
#               |-- train/
#               |   |-- airplane/
#               |   |   |-- 10008_airplane.png
#               |   |   |-- 10009_airplane.png
#               |   |   |-- ...
#               |   |
#               |   |-- automobile/
#               |   |   |-- 1000_automobile.png
#               |   |   |-- 1001_automobile.png
#               |   |   |-- ...
#               |   |
#               |   |-- bird/
#               |   |   |-- 10014_bird.png
#               |   |   |-- 10015_bird.png
#               |   |   |-- ...
#               |   |
#               |   |-- ...
#               |
#               |-- test/
#               |   |-- airplane/
#               |   |   |-- 10_airplane.png
#               |   |   |-- 11_airplane.png
#               |   |   |-- ...
#               |   |
#               |   |-- automobile/
#               |   |   |-- 100_automobile.png
#               |   |   |-- 101_automobile.png
#               |   |   |-- ...
#               |   |
#               |   |-- bird/
#               |   |   |-- 1000_bird.png
#               |   |   |-- 1001_bird.png
#               |   |   |-- ...
#               |   |
#               |   |-- ...

# %% [markdown]
# ## **Object Detection**

# %% [markdown]
# Object detection is a task that involves identifying the location and class of objects in an image or video stream.
#
# The output of an object detector is a set of bounding boxes that enclose the objects in the image, along with class labels and confidence scores for each box.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418624-5785cb93-74c9-4541-9179-d5c6782d491a.png" width="600">

# %% [markdown]
# **Labelling format**
#
# In object detection tasks, various labeling formats are used to annotate images with information about the objects present. These formats typically include details about the object's class and location within the image. Here are some of the most common labeling formats:
#
# 1. COCO
# 2. YOLO
# 3. CSV
# 5. XML
# 6. PASCAL VOC
#
# We will be discussing only YOLO format, as you will be using YOLO framework for your project:
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#
#       class_id bbox_x_center bbox_y_center bbox_width bbox_height
# - Box coordinates must be normalized between 0 and 1
#
#
# An example:

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/91506361-c7965000-e886-11ea-8291-c72b98c25eec.jpg" width="600">

# %% [markdown]
# Corresponding label text file should look like:
#
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/112467037-d2568c00-8d66-11eb-8796-55402ac0d62f.png" width="600">

# %% [markdown]
# ## **Segmentation**

# %% [markdown]
# Instance segmentation goes a step further than object detection and involves identifying individual objects in an image and segmenting them from the rest of the image.
#
# The output of an instance segmentation model is a set of masks or contours that outline each object in the image, along with class labels and confidence scores for each object. Instance segmentation is useful when you need to know not only where objects are in an image, but also what their exact shape is.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418644-7df320b8-098d-47f1-85c5-26604d761286.png" width="600">

# %% [markdown]
# **Labelling format for YOLO**
#
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#   - class index: An integer representing the class of the object (e.g., 0 for person, 1 for car, etc.).
#   - bounding coordinates: The bounding coordinates around the mask area, normalized to be between 0 and 1.
#
#
#       <class-index> <x1> <y1> <x2> <y2> ... <xn> <yn>
#
#
# Here is an example of the YOLO dataset format for a single image with two objects made up of a 3-point segment and a 5-point segment.
#
#
#       0 0.681 0.485 0.670 0.487 0.676 0.487
#       1 0.504 0.000 0.501 0.004 0.498 0.004 0.493 0.010 0.492 0.0104

# %% [markdown]
# ## **Pose Estimation**
# Pose estimation is a task that involves identifying the location of specific points in an image, usually referred to as keypoints. The keypoints can represent various parts of the object such as joints, landmarks, or other distinctive features. The locations of the keypoints are usually represented as a set of 2D [x, y] or 3D [x, y, visible] coordinates.
#
# The output of a pose estimation model is a set of points that represent the keypoints on an object in the image, usually along with the confidence scores for each point. Pose estimation is a good choice when you need to identify specific parts of an object in a scene, and their location in relation to each other.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418616-9811ac0b-a4a7-452a-8aba-484ba32bb4a8.png" width="600">

# %% [markdown]
# **Labelling format for YOLO**
#
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#   - Object class index: An integer representing the class of the object (e.g., 0 for person, 1 for car, etc.).
#   - Object center coordinates: The x and y coordinates of the center of the object, normalized to be between 0 and 1.
#   - Object width and height: The width and height of the object, normalized to be between 0 and 1.
#   - Object keypoint coordinates: The keypoints of the object, normalized to be between 0 and 1.
#
#
# Here is an example of the label format for pose estimation task:
#
# Format with Dim = 2
#
#       <class-index> <x> <y> <width> <height> <px1> <py1> <px2> <py2> ... <pxn> <pyn>
# Format with Dim = 3
#
#       <class-index> <x> <y> <width> <height> <px1> <py1> <p1-visibility> <px2> <py2> <p2-visibility> ... <pxn> <pyn> <p2-visibility>

# %%
from google.colab import drive
drive.mount('/content/drive')    # mount again
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-826335558.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')    # mount again
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     193       raise ValueError('Mountpoint must not be a symlink')
#     194     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 195       raise ValueError('Mountpoint must not already contain files')
#     196     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#     197       raise ValueError('Mountpoint must either be a directory or not exist')
#
# ValueError: Mountpoint must not already contain files

# %% [markdown]
# ## FOLDERS HEIRARCHY

# %% [markdown]
#  We need to convert the dataset into a specific heirarchy of folders for all the tasks except for task of classification.
#
#
# The directories should be in the following format:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **COCO128 Dataset**
#
# This section aims to introduce you to COCO dataset frequently used in Artificial Intelligence (AI).It is a foundational dataset in AI, widely used for tasks like object detection, segmentation, and image captioning.
#
#
# It Contains over 330,000 images with more than 200,000 labeled across 80 object categories. Unique for its richly annotated images, including object segmentation.It is widely used in computer vision research and has been used to train and evaluate many state-of-the-art object detection and segmentation models.
#
# Link to full dataset: https://cocodataset.org/#home

# %% [markdown]
# We are going using coco128 dataset.This dataset contains the first 128 images of COCO train 2017. It is used as the tutorial dataset for YOLO.
#
# Download the dataset from:
# https://www.kaggle.com/datasets/ultralytics/coco128/data

# %% [markdown]
# ## Dataset Visualization

# %% [markdown]
# To draw bounding boxes on images we need to understand the labelling format used by this dataset. The labels for this dataset are stored in YOLO format. i.e.
#
#         class_id bbox_x_center bbox_y_center bbox_width bbox_height

# %% [markdown]
# The class_id is the numerical number assigned to different class labels as shown below:

# %%
# ✅ Full Fire and Smoke Intensity Classes (plain text only)
class_labels = {
    0: "Fire",
    1: "Serious Smoke",
    2: "Moderate Smoke",
    3: "Mild Smoke",
    4: "Steam / False Alarm",
    5: "Non-Fire Smoke",
    6: "Incense / Non-Threat Smoke"
}

# %% [markdown]
# same bounding box for all to make sure all data is collected for confusion matrix

# %%
def draw_yolo_bbox(image_path, label_path):
    # Load image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    height, width, _ = image.shape

    # Read label file
    with open(label_path, 'r') as file:
        bboxes = file.readlines()

    # Draw each bbox
    for bbox in bboxes:
        class_id, x_center, y_center, bbox_width, bbox_height = [float(x) for x in bbox.split()]

        # Convert YOLO bbox format to rectangle coordinates
        x1 = int((x_center - bbox_width / 2) * width)
        y1 = int((y_center - bbox_height / 2) * height)
        x2 = int((x_center + bbox_width / 2) * width)
        y2 = int((y_center + bbox_height / 2) * height)

        # Draw rectangle
        cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
        # Put label (class_id) near the bbox
        label = class_labels[int(class_id)]
        cv2.putText(image, label, (x1, y1+20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
    # Display image
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %% [markdown]
# The rest of the four values i.e.
#
#     0.479492 0.688771 0.955609 0.5955
#
# indidicate the location of the bounding box.
#
# These values are normalized, which should be converted to a format that can be used as coordinate values of rectangle function (of cv2).

# %% [markdown]
# First import the required libraries:

# %%
import cv2
import matplotlib.pyplot as plt
import random as random
import os

# %% [markdown]
# Set all the paths of the dataset:

# %%
import os

# Set the path to Dataset 1
dataset_path = "/content/drive/MyDrive/dataset 1"

# Collect all image paths from train and val subfolders
image_paths = []
for subfolder in ["train", "val"]:
    folder = os.path.join(dataset_path, "images", subfolder)
    if os.path.exists(folder):
        for image_name in os.listdir(folder):
            if image_name.lower().endswith((".jpg", ".jpeg", ".png")):
                image_paths.append(os.path.join(folder, image_name))

# Collect all label paths from train and val subfolders
label_paths = []
for subfolder in ["train", "val"]:
    folder = os.path.join(dataset_path, "labels", subfolder)
    if os.path.exists(folder):
        for label_name in os.listdir(folder):
            if label_name.endswith(".txt"):
                label_paths.append(os.path.join(folder, label_name))

# Print results
print(f"📸 Total images in Dataset 1: {len(image_paths)}")
print(f"🧾 Total labels in Dataset 1: {len(label_paths)}")
print("\nSample images:")
print(image_paths[:5])

# %%
import os

# ============================================================
# Dataset 2 — List all image and label paths
# ============================================================
dataset_path = "/content/drive/MyDrive/dataset 2"

# Collect all image paths from train and val folders
image_root = os.path.join(dataset_path, "images")
image_paths = []
for subdir in ["train", "val"]:
    subdir_path = os.path.join(image_root, subdir)
    if os.path.exists(subdir_path):
        for image_name in os.listdir(subdir_path):
            image_paths.append(os.path.join(subdir_path, image_name))

# Collect all label paths from train and val folders
label_root = os.path.join(dataset_path, "labels")
label_paths = []
for subdir in ["train", "val"]:
    subdir_path = os.path.join(label_root, subdir)
    if os.path.exists(subdir_path):
        for label_name in os.listdir(subdir_path):
            label_paths.append(os.path.join(subdir_path, label_name))

# ============================================================
# Print results
# ============================================================
print("📸 Image Paths:")
print(image_paths[:10])  # show first 10 for preview

print("\n🗒️ Label Paths:")
print(label_paths[:10])

print(f"\n✅ Total images: {len(image_paths)}")
print(f"✅ Total labels: {len(label_paths)}")

# %%
# Set the path to the dataset
dataset_path = "/content/drive/MyDrive/Home fire dataset/test"

# Get the list of all images paths in the dataset
image_paths = [os.path.join(dataset_path, "images", image_name) for image_name in os.listdir(os.path.join(dataset_path, "images"))]

# Get the list of all labels paths in the dataset
label_paths = [os.path.join(dataset_path, "labels", label_name) for label_name in os.listdir(os.path.join(dataset_path, "labels"))]

print (image_paths)

# %% [markdown]
# Set all the paths of the dataset of Fire and Smoke:

# %%
import os

dataset_root = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128"
annotations_json = os.path.join(dataset_root, "annotations", "instances_val2017.json")

# Check if JSON exists
if os.path.exists(annotations_json):
    print(f"✅ JSON found at: {annotations_json}")
else:
    print(f"❌ JSON NOT found! Current working dir: {os.getcwd()}")
    # List contents of dataset_root to see folder names
    print("Contents of dataset_root:", os.listdir(dataset_root))
    # List contents of annotations folder
    annotations_folder = os.path.join(dataset_root, "annotations")
    if os.path.exists(annotations_folder):
        print("Contents of annotations folder:", os.listdir(annotations_folder))
    else:
        print("Annotations folder not found!")

dataset_root = "Fire and Smoke BBox COCO Dateset/coco128"
for root, dirs, files in os.walk(dataset_root):
    for file in files:
        if file.endswith(".json"):
            print("Found JSON:", os.path.join(root, file))

# %%
import os
from pathlib import Path
import json
from PIL import Image
from collections import defaultdict
from tqdm import tqdm

# ============================================================
# 1️⃣ Dataset Paths — Auto Setup
# ============================================================
dataset_root = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128"

images_dir = os.path.join(dataset_root, "val2017")
annotations_dir = os.path.join(dataset_root, "annotations")
json_file = os.path.join(annotations_dir, "instances_train2017.json")
labels_dir = os.path.join(dataset_root, "labels", "train")

os.makedirs(labels_dir, exist_ok=True)

# Sanity checks
if not os.path.exists(images_dir):
    raise FileNotFoundError(f"❌ Image folder missing: {images_dir}")
if not os.path.exists(json_file):
    raise FileNotFoundError(f"❌ COCO JSON not found: {json_file}")

print(f"✅ Image path: {images_dir}")
print(f"✅ JSON file:  {json_file}")
print(f"✅ Output dir: {labels_dir}")

# ============================================================
# 2️⃣ Load COCO JSON
# ============================================================
with open(json_file, "r") as f:
    coco = json.load(f)

# Validate COCO structure
required_keys = {"images", "annotations", "categories"}
if not required_keys.issubset(coco.keys()):
    raise ValueError(f"❌ Invalid COCO structure. Missing keys: {required_keys - set(coco.keys())}")

# Map image_id → filename and size
img_id2file = {img['id']: img['file_name'] for img in coco['images']}
img_id2size = {img['id']: (img['width'], img['height']) for img in coco['images']}

# Group annotations per image
img_annotations = defaultdict(list)
for ann in coco['annotations']:
    if ann.get('bbox') and ann['bbox'][2] > 0 and ann['bbox'][3] > 0:
        img_annotations[ann['image_id']].append(ann)

print(f"📊 Total images in JSON:      {len(img_id2file)}")
print(f"📊 Images with annotations:   {len(img_annotations)}")

# ============================================================
# 3️⃣ Convert COCO → YOLO format
# ============================================================
for img_id, anns in tqdm(img_annotations.items(), desc="Converting COCO → YOLO TXT"):
    img_name = img_id2file[img_id]
    img_path = os.path.join(images_dir, img_name)
    txt_path = os.path.join(labels_dir, Path(img_name).stem + ".txt")

    # Retrieve image dimensions
    if os.path.exists(img_path):
        try:
            with Image.open(img_path) as im:
                w, h = im.size
        except Exception:
            w, h = img_id2size.get(img_id, (640, 480))
    else:
        w, h = img_id2size.get(img_id, (640, 480))

    # Write YOLO annotation file
    with open(txt_path, "w") as f:
        for ann in anns:
            cid = ann["category_id"] - 1  # COCO is 1-indexed
            x_min, y_min, box_w, box_h = ann["bbox"]

            if box_w <= 0 or box_h <= 0:
                continue

            x_center = (x_min + box_w / 2) / w
            y_center = (y_min + box_h / 2) / h
            width_norm = box_w / w
            height_norm = box_h / h

            f.write(f"{cid} {x_center:.6f} {y_center:.6f} {width_norm:.6f} {height_norm:.6f}\n")

# ============================================================
# 4️⃣ Verify results (no display)
# ============================================================
txt_files = [f for f in os.listdir(labels_dir) if f.endswith(".txt")]
if not txt_files:
    raise RuntimeError("❌ No YOLO .txt labels were generated. Check your JSON data.")
else:
    print(f"✅ Successfully created {len(txt_files)} YOLO label files.")

print("🎯 Conversion complete. All annotations exported cleanly.")

# %% [markdown]
# Updated fix

# %%
import os, random
from pathlib import Path
from PIL import Image

# ============================================================
# 1️⃣ Dataset Paths
# ============================================================
dataset_root = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128"
images_dir = os.path.join(dataset_root, "val2017")
labels_dir = os.path.join(dataset_root, "labels", "val")

# ============================================================
# 2️⃣ Class Labels
# ============================================================
class_labels = {
    0: "Fire",
    1: "Smoke",
    2: "Smoke",
    3: "Smoke",
    4: "Steam",
    5: "Non-Fire Smoke",
    6: "Incense"
}

# ============================================================
# 3️⃣ Intensity & Visibility (Data-Based)
# ============================================================
def analyze_intensity(img, bbox, cid):
    from PIL import ImageStat
    x1, y1, x2, y2 = bbox
    region = img.crop((x1, y1, x2, y2)).convert("RGB")
    stat = ImageStat.Stat(region)
    brightness = sum(stat.mean) / (3 * 255)
    contrast = sum(stat.stddev) / (3 * 128)

    if cid == 0:
        if brightness > 0.7 and contrast > 0.5:
            return "High Intensity (Flames Visible)"
        elif brightness > 0.45:
            return "Moderate Intensity (Active Burn)"
        else:
            return "Low Intensity (Smoldering Fire)"
    elif cid in [1, 2, 3, 5]:
        if brightness < 0.25 and contrast < 0.3:
            return "Dense Smoke (Low Visibility)"
        elif brightness < 0.5:
            return "Moderate Smoke (Partial Visibility)"
        else:
            return "Light Smoke (Thin Haze)"
    elif cid == 4:
        return "Steam Cloud (Reflected Light)"
    elif cid == 6:
        return "Incense (Light Diffusion)"
    else:
        return "Unclassified"

# ============================================================
# 4️⃣ Parse YOLO TXT — data-only
# ============================================================
def parse_yolo_label(txt_path, w, h):
    boxes = []
    with open(txt_path, "r") as f:
        for line in f.readlines():
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cid, xc, yc, bw, bh = map(float, parts[:5])
            # convert from normalized → pixels
            xc, yc, bw, bh = xc * w, yc * h, bw * w, bh * h
            x1, y1, x2, y2 = int(xc - bw / 2), int(yc - bh / 2), int(xc + bw / 2), int(yc + bh / 2)
            boxes.append((int(cid), (x1, y1, x2, y2)))
    return boxes

# ============================================================
# 5️⃣ DATA-ONLY DISPLAY (no visuals, no aesthetics)
# ============================================================
def show_label_data_only(n=10):
    image_exts = (".jpg", ".jpeg", ".png")
    image_stems = {Path(f).stem for f in os.listdir(images_dir) if f.lower().endswith(image_exts)}
    label_stems = {Path(f).stem for f in os.listdir(labels_dir) if f.endswith(".txt")}
    matched = sorted(image_stems & label_stems)

    if not matched:
        print("⚠️ No matching image–label pairs found!")
        return

    print(f"\n📄 Showing {min(n, len(matched))} data-based detections (no visuals)...\n")

    for stem in random.sample(matched, min(n, len(matched))):
        img_path = next((os.path.join(images_dir, stem + ext)
                         for ext in image_exts if os.path.exists(os.path.join(images_dir, stem + ext))), None)
        txt_path = os.path.join(labels_dir, stem + ".txt")
        if not img_path or not os.path.exists(txt_path):
            continue

        img = Image.open(img_path).convert("RGB")
        w, h = img.size
        boxes = parse_yolo_label(txt_path, w, h)

        print(f"📷 {stem}.jpg ({w}x{h}) — {len(boxes)} detections:")
        for cid, (x1, y1, x2, y2) in boxes:
            cname = class_labels.get(cid, "Unknown")
            intensity = analyze_intensity(img, (x1, y1, x2, y2), cid)
            print(f"   - Class: {cname} | Intensity: {intensity}")
            print(f"     Bounding Box (px): {x1, y1, x2, y2}")
        print("-" * 80)

# ============================================================
# 6️⃣ Run — Data-Only Summary
# ============================================================
show_label_data_only(n=20)

# %%
import os, random
from pathlib import Path
from PIL import Image, ImageDraw
from IPython.display import display

# ============================================================
# 1️⃣ Directories
# ============================================================
images_dir = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/val2017"
labels_dir = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/labels/val"
save_dir = "/content/drive/MyDrive/fire_smoke_previews/data_labels_output"
os.makedirs(save_dir, exist_ok=True)

# ============================================================
# 2️⃣ Parse .txt — use *all numeric values as-is*
# ============================================================
def parse_yolo_label(txt_path, w, h):
    """Reads YOLO labels and converts to bounding boxes using all .txt numbers."""
    boxes = []
    if not os.path.exists(txt_path):
        return boxes

    with open(txt_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue

            # extract all values
            cid = int(float(parts[0]))
            vals = list(map(float, parts[1:5]))

            # determine if normalized or absolute coordinates
            if all(0 <= v <= 1 for v in vals):
                xc, yc, bw, bh = vals
                x1 = int((xc - bw / 2) * w)
                y1 = int((yc - bh / 2) * h)
                x2 = int((xc + bw / 2) * w)
                y2 = int((yc + bh / 2) * h)
            else:
                # if absolute
                x1, y1, x2, y2 = map(int, vals)

            # append including raw numbers (for later display)
            boxes.append((cid, (x1, y1, x2, y2), vals))
    return boxes

# ============================================================
# 3️⃣ Draw Bounding Boxes (include txt numbers)
# ============================================================
def draw_true_labels(img_path, txt_path):
    img = Image.open(img_path).convert("RGB")
    w, h = img.size
    boxes = parse_yolo_label(txt_path, w, h)
    if not boxes:
        return img, 0
    draw = ImageDraw.Draw(img)
    for cid, (x1, y1, x2, y2), vals in boxes:
        color = (0, 255, 255)
        draw.rectangle((x1, y1, x2, y2), outline=color, width=2)

        # show ID + actual txt file numbers
        vals_str = ", ".join(f"{v:.6f}" for v in vals)
        label_text = f"ID{cid}: [{vals_str}]"
        draw.text((x1 + 3, y1 - 12), label_text, fill=color)

    return img, len(boxes)

# ============================================================
# 4️⃣ Display and Save Images
# ============================================================
def display_and_save_data_labels(n=5):
    image_exts = (".jpg", ".jpeg", ".png")
    image_stems = {Path(f).stem for f in os.listdir(images_dir) if f.lower().endswith(image_exts)}
    label_stems = {Path(f).stem for f in os.listdir(labels_dir) if f.endswith(".txt")}
    matched = sorted(image_stems & label_stems)

    print(f"\n📸 Displaying {min(n, len(matched))} exact data-based annotations...\n")
    for stem in random.sample(matched, min(n, len(matched))):
        img_path = next((os.path.join(images_dir, stem + ext)
                         for ext in image_exts if os.path.exists(os.path.join(images_dir, stem + ext))), None)
        txt_path = os.path.join(labels_dir, stem + ".txt")
        if not img_path or not os.path.exists(txt_path):
            continue

        img, count = draw_true_labels(img_path, txt_path)
        display(img)
        print(f"✅ {stem}.jpg — {count} boxes (from txt values)")

        save_path = os.path.join(save_dir, f"{stem}_from_txt.jpg")
        img.save(save_path)

    print(f"\n💾 Saved annotated images to: {save_dir}\n")

# ============================================================
# 5️⃣ Run
# ============================================================
display_and_save_data_labels(n=10)

# %%
from pathlib import Path
image_stems = sorted([Path(f).stem for f in os.listdir(images_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))])
label_stems = sorted([Path(f).stem for f in os.listdir(labels_dir) if f.endswith('.txt')])

print("🖼️  First 10 image names:", image_stems[:10])
print("📝 First 10 label names:", label_stems[:10])
print("🔎 Common stems:", len(set(image_stems) & set(label_stems)))

# %%
import os, shutil
img_dir = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/val2017"
lbl_dir = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/labels/val"

img_stems = {os.path.splitext(f)[0] for f in os.listdir(img_dir) if f.endswith(('.jpg','.png'))}
for lbl in os.listdir(lbl_dir):
    if not lbl.endswith('.txt'): continue
    old_path = os.path.join(lbl_dir, lbl)
    base = os.path.splitext(lbl)[0]
    # find any image name that starts with same digits
    match = next((i for i in img_stems if i in base or base in i), None)
    if match and base != match:
        new_path = os.path.join(lbl_dir, f"{match}.txt")
        shutil.move(old_path, new_path)
        print(f"🔧 Renamed {lbl} → {match}.txt")

# %% [markdown]
# validate the images

# %%
import os
from pathlib import Path

images_dir = "/content/drive/MyDrive/Home fire dataset/test/images"
labels_dir = "/content/drive/MyDrive/Home fire dataset/test/labels"

image_exts = (".jpg", ".jpeg", ".png")
image_stems = {Path(f).stem for f in os.listdir(images_dir) if f.lower().endswith(image_exts)}
label_stems = {Path(f).stem for f in os.listdir(labels_dir) if f.endswith(".txt")}

missing_images = sorted(label_stems - image_stems)
extra_images = sorted(image_stems - label_stems)

# Delete YOLO txts that don’t match an image
for stem in missing_images:
    os.remove(os.path.join(labels_dir, f"{stem}.txt"))

print(f"✅ Kept {len(image_stems & label_stems)} valid image–label pairs.")
print(f"🗑️ Removed {len(missing_images)} orphan label files (no matching image).")
if extra_images:
    print(f"⚠️ {len(extra_images)} images have no label files (you can auto-generate later).")

# %%
from pathlib import Path
image_stems = {Path(f).stem for f in os.listdir(images_dir)}
label_stems = {Path(f).stem for f in os.listdir(labels_dir)}
matched = image_stems & label_stems
print(f"✅ Matched pairs: {len(matched)} / {len(image_stems)} images")

# %% [markdown]
# validate images

# %%
import os
from pathlib import Path

# ============================================================
# 1️⃣ Set paths for Dataset 1 (with nested train/val folders)
# ============================================================
dataset_root = "/content/drive/MyDrive/dataset 1"
images_root = os.path.join(dataset_root, "images")
labels_root = os.path.join(dataset_root, "labels")

image_exts = (".jpg", ".jpeg", ".png")

# Collect all images recursively
image_files = [p for p in Path(images_root).rglob("*") if p.suffix.lower() in image_exts]
label_files = [p for p in Path(labels_root).rglob("*.txt")]

image_stems = {f.stem for f in image_files}
label_stems = {f.stem for f in label_files}

missing_images = sorted(label_stems - image_stems)
extra_images = sorted(image_stems - label_stems)

# ============================================================
# 2️⃣ Delete orphan labels (no matching image)
# ============================================================
for stem in missing_images:
    for lbl in Path(labels_root).rglob(f"{stem}.txt"):
        os.remove(lbl)

print(f"✅ Kept {len(image_stems & label_stems)} valid image–label pairs in Dataset 1.")
print(f"🗑️ Removed {len(missing_images)} orphan label files (no matching image).")
if extra_images:
    print(f"⚠️ {len(extra_images)} images have no label files (you can auto-generate later).")

# Sanity check
matched = image_stems & label_stems
print(f"📊 Matched pairs: {len(matched)} / {len(image_stems)} images")

# %%
import os
from pathlib import Path

# ============================================================
# 1️⃣ Set paths for Dataset 2 (with nested train/val folders)
# ============================================================
dataset_root = "/content/drive/MyDrive/dataset 2"
images_root = os.path.join(dataset_root, "images")
labels_root = os.path.join(dataset_root, "labels")

image_exts = (".jpg", ".jpeg", ".png")

# Collect all images recursively
image_files = [p for p in Path(images_root).rglob("*") if p.suffix.lower() in image_exts]
label_files = [p for p in Path(labels_root).rglob("*.txt")]

image_stems = {f.stem for f in image_files}
label_stems = {f.stem for f in label_files}

missing_images = sorted(label_stems - image_stems)
extra_images = sorted(image_stems - label_stems)

# ============================================================
# 2️⃣ Delete orphan labels (no matching image)
# ============================================================
for stem in missing_images:
    for lbl in Path(labels_root).rglob(f"{stem}.txt"):
        os.remove(lbl)

print(f"✅ Kept {len(image_stems & label_stems)} valid image–label pairs in Dataset 2.")
print(f"🗑️ Removed {len(missing_images)} orphan label files (no matching image).")
if extra_images:
    print(f"⚠️ {len(extra_images)} images have no label files (you can auto-generate later).")

# Sanity check
matched = image_stems & label_stems
print(f"📊 Matched pairs: {len(matched)} / {len(image_stems)} images")

# %%
import os, random
from pathlib import Path
from PIL import Image, ImageDraw, ImageStat
from IPython.display import display

# ============================================================
# 1️⃣ Paths
# ============================================================
images_dir = "/content/drive/MyDrive/Home fire dataset/test/images"
labels_dir = "/content/drive/MyDrive/Home fire dataset/test/labels"

# ============================================================
# 2️⃣ Base Class Names (NO Emojis)
# ============================================================
class_labels = {
    0: "Fire",
    1: "Smoke",
    2: "Smoke",
    3: "Smoke",
    4: "Steam",
    5: "Non-Fire Smoke",
    6: "Incense"
}

# ============================================================
# 3️⃣ YOLO TXT → Bounding Boxes
# ============================================================
def yolo_to_bbox(line, w, h):
    parts = line.strip().split()
    if len(parts) < 5:
        return None, None
    cid, xc, yc, bw, bh = map(float, parts[:5])
    xc, yc, bw, bh = xc * w, yc * h, bw * w, bh * h
    return int(cid), (int(xc - bw / 2), int(yc - bh / 2), int(xc + bw / 2), int(yc + bh / 2))

# ============================================================
# 4️⃣ Analyze Intensity (based on brightness & contrast)
# ============================================================
def analyze_intensity(img, bbox, cid):
    x1, y1, x2, y2 = bbox
    region = img.crop((x1, y1, x2, y2)).convert("RGB")
    stat = ImageStat.Stat(region)
    brightness = sum(stat.mean) / (3 * 255)
    contrast = sum(stat.stddev) / (3 * 128)

    if cid == 0:  # 🔥 FIRE
        if brightness > 0.7 and contrast > 0.5:
            return "High Intensity (Flames Visible)"
        elif brightness > 0.45:
            return "Medium Intensity (Active Burn)"
        else:
            return "Low Intensity (Smoldering Fire)"
    elif cid in [1, 2, 3, 5]:  # 💨 SMOKE
        if brightness < 0.25 and contrast < 0.3:
            return "Dense Smoke (Low Visibility)"
        elif brightness < 0.5:
            return "Moderate Smoke (Partial Visibility)"
        else:
            return "Light Smoke (Thin Haze)"
    elif cid == 4:
        return "Steam (Reflected Light)"
    elif cid == 6:
        return "Incense / Light Diffusion"
    else:
        return "Unclassified"

# ============================================================
# 5️⃣ Display Clean Annotated Images
# ============================================================
def display_clean_annotations(images_dir, labels_dir, n=10):
    image_exts = (".jpg", ".jpeg", ".png")
    image_stems = {Path(f).stem for f in os.listdir(images_dir) if f.lower().endswith(image_exts)}
    label_stems = {Path(f).stem for f in os.listdir(labels_dir) if f.endswith(".txt")}
    matched = sorted(image_stems & label_stems)

    print(f"\n📂 Displaying {min(n, len(matched))} labeled samples (of {len(matched)} total)...\n")

    for stem in random.sample(matched, min(n, len(matched))):
        img_path = os.path.join(images_dir, stem + ".jpg")
        txt_path = os.path.join(labels_dir, stem + ".txt")
        if not os.path.exists(img_path) or not os.path.exists(txt_path):
            continue

        img = Image.open(img_path).convert("RGB")
        draw = ImageDraw.Draw(img)
        w, h = img.size

        with open(txt_path) as f:
            for line in f:
                cid, bbox = yolo_to_bbox(line, w, h)
                if not bbox:
                    continue
                intensity = analyze_intensity(img, bbox, cid)
                cname = class_labels.get(cid, "Unknown")

                label_text = f"{cname} — {intensity}"
                draw.rectangle(bbox, outline=(255, 255, 255), width=2)
                draw.text((bbox[0] + 2, bbox[1] - 14), label_text, fill=(255, 255, 255))
                print(f"{stem}.jpg → {label_text}")

        display(img)
        print(f"✅ Displayed: {stem}.jpg\n")

# ============================================================
# 6️⃣ Run (Clean Label Alignment)
# ============================================================
display_clean_annotations(images_dir, labels_dir, n=25)

# %% [markdown]
# Datasets NEW

# %%
import os, random
from pathlib import Path
from PIL import Image, ImageDraw, ImageStat
from IPython.display import display

# ============================================================
# 1️⃣ PATHS — DATASET 1
# ============================================================
# 🔹 Switch between "train" and "val" easily
images_dir = "/content/drive/MyDrive/dataset 1/images/train"
labels_dir = "/content/drive/MyDrive/dataset 1/labels/train"

# ============================================================
# 2️⃣ BASE LABELS — simplified, no emojis
# ============================================================
class_labels = {
    0: "Fire",
    1: "Smoke",
    2: "Smoke",
    3: "Smoke",
    4: "Steam",
    5: "Non-Fire Smoke",
    6: "Incense"
}

# ============================================================
# 3️⃣ YOLO TXT → BBox
# ============================================================
def yolo_to_bbox(line, w, h):
    parts = line.strip().split()
    if len(parts) != 5:
        return None, None
    cid, xc, yc, bw, bh = map(float, parts)
    xc, yc, bw, bh = xc * w, yc * h, bw * w, bh * h
    return int(cid), (int(xc - bw / 2), int(yc - bh / 2), int(xc + bw / 2), int(yc + bh / 2))

# ============================================================
# 4️⃣ Brightness & Contrast Analyzer
# ============================================================
def analyze_visibility(img, bbox):
    x1, y1, x2, y2 = bbox
    region = img.crop((x1, y1, x2, y2)).convert("RGB")
    stat = ImageStat.Stat(region)
    brightness = sum(stat.mean) / (3 * 255)
    contrast = sum(stat.stddev) / (3 * 128)
    return brightness, contrast

# ============================================================
# 5️⃣ Intensity Classification System
# ============================================================
def classify_intensity(cid, brightness, contrast):
    """Returns a plain-text intensity or density description based on pixel stats."""
    if cid == 0:  # Fire
        if brightness > 0.7 and contrast > 0.5:
            return "High Intensity (Flames Visible)"
        elif brightness > 0.45:
            return "Moderate Intensity (Active Burn)"
        else:
            return "Low Intensity (Smoldering)"
    elif cid in [1, 2, 3, 5]:  # Smoke
        if brightness < 0.25 and contrast < 0.3:
            return "Dense Smoke (Low Visibility)"
        elif brightness < 0.5:
            return "Moderate Smoke (Partial Visibility)"
        else:
            return "Light Smoke (Thin Haze)"
    elif cid == 4:
        return "Steam Cloud (Reflected Light)"
    elif cid == 6:
        return "Incense Diffusion"
    return "Unclassified"

# ============================================================
# 6️⃣ DISPLAY FUNCTION — Clean Text Labels Only
# ============================================================
def display_clean_labels(images_dir, labels_dir, n=10):
    image_exts = (".jpg", ".jpeg", ".png")
    image_stems = {Path(f).stem for f in os.listdir(images_dir) if f.lower().endswith(image_exts)}
    label_stems = {Path(f).stem for f in os.listdir(labels_dir) if f.endswith(".txt")}
    matched = sorted(image_stems & label_stems)

    print(f"\n📂 Displaying {min(n, len(matched))} annotated samples (of {len(matched)} total)…\n")

    for stem in random.sample(matched, min(n, len(matched))):
        img_path = next((os.path.join(images_dir, stem + ext)
                         for ext in image_exts if os.path.exists(os.path.join(images_dir, stem + ext))), None)
        txt_path = os.path.join(labels_dir, stem + ".txt")
        if not img_path or not os.path.exists(txt_path):
            continue

        img = Image.open(img_path).convert("RGB")
        draw = ImageDraw.Draw(img)
        w, h = img.size

        with open(txt_path) as f:
            for line in f.readlines():
                cid, bbox = yolo_to_bbox(line, w, h)
                if not bbox:
                    continue

                brightness, contrast = analyze_visibility(img, bbox)
                cname = class_labels.get(cid, "Unknown")
                intensity = classify_intensity(cid, brightness, contrast)

                label_text = f"{cname} — {intensity}"
                draw.rectangle(bbox, outline=(255, 255, 255), width=2)
                draw.text((bbox[0] + 2, bbox[1] - 14), label_text, fill=(255, 255, 255))

        display(img)
        print(f"✅ {stem}.jpg | {label_text}")
        print("-" * 70)

# ============================================================
# 7️⃣ RUN
# ============================================================
display_clean_labels(images_dir, labels_dir, n=20)

# %%
import os
import cv2
import random
import matplotlib.pyplot as plt

# ============================================================
# 1️⃣ Dataset 2 Paths
# ============================================================
dataset_path = "/content/drive/MyDrive/dataset 2"
image_root = os.path.join(dataset_path, "images")
label_root = os.path.join(dataset_path, "labels")

# Load all image paths (train + val)
image_paths = []
for split in ["train", "val"]:
    split_dir = os.path.join(image_root, split)
    if os.path.exists(split_dir):
        for img_name in os.listdir(split_dir):
            if img_name.lower().endswith((".jpg", ".jpeg", ".png")):
                image_paths.append(os.path.join(split_dir, img_name))

# ============================================================
# 2️⃣ Draw Bounding Boxes (pure YOLO data)
# ============================================================
def draw_yolo_bbox(image_path, label_path):
    """Draw rectangles using class numbers directly from .txt."""
    image = cv2.imread(image_path)
    if image is None:
        print(f"⚠️ Could not read image: {image_path}")
        return
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    height, width, _ = image.shape

    if not os.path.exists(label_path):
        print(f"⚠️ Missing label: {label_path}")
        return

    with open(label_path, 'r') as file:
        bboxes = file.readlines()

    # Draw each bounding box directly from data
    for bbox in bboxes:
        parts = bbox.strip().split()
        if len(parts) < 5:
            continue
        class_id, x_center, y_center, bbox_width, bbox_height = [float(x) for x in parts[:5]]

        # Convert normalized YOLO format → pixel rectangle
        x1 = int((x_center - bbox_width / 2) * width)
        y1 = int((y_center - bbox_height / 2) * height)
        x2 = int((x_center + bbox_width / 2) * width)
        y2 = int((y_center + bbox_height / 2) * height)

        # Draw data-based box (no aesthetic style)
        color = (0, 255, 255)
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)

        # Show class number directly from txt
        class_text = f"Class {int(class_id)}"
        cv2.putText(image, class_text, (x1, max(y1 - 10, 10)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2, cv2.LINE_AA)

    # Display image (true YOLO annotations)
    plt.figure(figsize=(8, 6))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# ============================================================
# 3️⃣ Display Random Data-Based Images
# ============================================================
def print_random_images(photos: list, n: int = 5):
    for _ in range(n):
        random_photo_path = random.choice(photos)
        name = os.path.splitext(os.path.basename(random_photo_path))[0]

        # Look for label in train or val folder
        found_label = False
        for split in ["train", "val"]:
            label_path = os.path.join(label_root, split, f"{name}.txt")
            if os.path.exists(label_path):
                print(f"\n📷 Displaying {name}.jpg with numeric labels from {split}...")
                draw_yolo_bbox(random_photo_path, label_path)
                found_label = True
                break

        if not found_label:
            print(f"🚫 No label found for {name}.jpg")

# ============================================================
# 4️⃣ Run Display
# ============================================================
print_random_images(image_paths, n=6)

# %%
import os, random
from pathlib import Path
from PIL import Image, ImageDraw, ImageStat
from IPython.display import display

# ============================================================
# 1️⃣ GLOBAL SETTINGS — ALL DATASETS
# ============================================================
datasets = {
    "Fire_Smoke_COCO": {
        "images": "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/val2017",
        "labels": "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/labels/val"
    },
    "Home_Fire_Test": {
        "images": "/content/drive/MyDrive/Home fire dataset/test/images",
        "labels": "/content/drive/MyDrive/Home fire dataset/test/labels"
    },
    "Dataset_1": {
        "images": "/content/drive/MyDrive/dataset 1/images/train",
        "labels": "/content/drive/MyDrive/dataset 1/labels/train"
    },
    "Dataset_2": {
        "images": "/content/drive/MyDrive/dataset 2/images/train",
        "labels": "/content/drive/MyDrive/dataset 2/labels/train"
    }
}

class_labels = {
    0: "Fire",
    1: "Smoke",
    2: "Smoke",
    3: "Smoke",
    4: "Steam",
    5: "Non-Fire Smoke",
    6: "Incense"
}

# ============================================================
# 2️⃣ HELPERS — YOLO PARSING + BRIGHTNESS ANALYSIS
# ============================================================
def yolo_to_bbox(line, w, h):
    parts = line.strip().split()
    if len(parts) < 5:
        return None, None
    cid, xc, yc, bw, bh = map(float, parts[:5])
    xc, yc, bw, bh = xc * w, yc * h, bw * w, bh * h
    return int(cid), (int(xc - bw/2), int(yc - bh/2), int(xc + bw/2), int(yc + bh/2))

def analyze_region(img, bbox):
    x1, y1, x2, y2 = bbox
    region = img.crop((x1, y1, x2, y2)).convert("L")
    stat = ImageStat.Stat(region)
    brightness = stat.mean[0] / 255
    contrast = stat.stddev[0] / 128
    return brightness, contrast

# ============================================================
# 3️⃣ INTENSITY CLASSIFIER
# ============================================================
def classify_intensity(cid, brightness, contrast):
    if cid == 0:  # Fire
        if brightness > 0.7 and contrast > 0.5:
            return "High Intensity (Flames Visible)"
        elif brightness > 0.45:
            return "Moderate Intensity (Active Burn)"
        else:
            return "Low Intensity (Smoldering)"
    elif cid in [1, 2, 3, 5]:  # Smoke
        if brightness < 0.25 and contrast < 0.3:
            return "Dense Smoke (Low Visibility)"
        elif brightness < 0.5:
            return "Moderate Smoke (Partial Visibility)"
        else:
            return "Light Smoke (Thin Haze)"
    elif cid == 4:
        return "Steam Cloud (Reflected Light)"
    elif cid == 6:
        return "Incense Diffusion"
    return "Unclassified"

# ============================================================
# 4️⃣ OBJECT DETECTION + TEXT LABEL DISPLAY
# ============================================================
def display_detections(images_dir, labels_dir, dataset_name, n=10):
    image_exts = (".jpg", ".jpeg", ".png")
    image_stems = {Path(f).stem for f in os.listdir(images_dir) if f.lower().endswith(image_exts)}
    label_stems = {Path(f).stem for f in os.listdir(labels_dir) if f.endswith(".txt")}
    matched = sorted(image_stems & label_stems)

    print(f"\n📦 Dataset: {dataset_name}")
    print(f"📸 Found {len(matched)} valid image–label pairs.\n")

    for stem in random.sample(matched, min(n, len(matched))):
        img_path = next((os.path.join(images_dir, stem + ext)
                         for ext in image_exts if os.path.exists(os.path.join(images_dir, stem + ext))), None)
        txt_path = os.path.join(labels_dir, stem + ".txt")
        if not img_path or not os.path.exists(txt_path):
            continue

        img = Image.open(img_path).convert("RGB")
        draw = ImageDraw.Draw(img)
        w, h = img.size

        detections = []
        with open(txt_path) as f:
            for line in f.readlines():
                cid, bbox = yolo_to_bbox(line, w, h)
                if not bbox:
                    continue
                brightness, contrast = analyze_region(img, bbox)
                cname = class_labels.get(cid, "Unknown")
                intensity = classify_intensity(cid, brightness, contrast)
                detections.append((cname, intensity, bbox))

        # Draw detections (text only)
        for cname, intensity, bbox in detections:
            label_text = f"{cname} — {intensity}"
            draw.rectangle(bbox, outline=(255, 255, 255), width=2)
            draw.text((bbox[0] + 2, bbox[1] - 14), label_text, fill=(255, 255, 255))

        # Display annotated image
        display(img)

        # Print summary in terminal
        print(f"✅ {stem}.jpg | {len(detections)} objects detected")
        for cname, intensity, bbox in detections:
            print(f"   - {cname}: {intensity}  |  bbox={bbox}")
        print("-" * 70)

# ============================================================
# 5️⃣ RUN DETECTIONS FOR ALL DATASETS
# ============================================================
for name, paths in datasets.items():
    display_detections(paths["images"], paths["labels"], name, n=10)

# %% [markdown]
# The funtion "draw_yolo_box", takes input an image path and its corresponding label path. Then, draws the bounding boxes and write the object's label in each box. Finally it displays the images

# %%
def draw_yolo_bbox(image_path, label_path):
    # Load image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    height, width, _ = image.shape

    # Read label file
    with open(label_path, 'r') as file:
        bboxes = file.readlines()

    # Draw each bbox
    for bbox in bboxes:
        cls, x_center, y_center, w, h = map(float, bbox.strip().split())
        x1 = int((x_center - w / 2) * width)
        y1 = int((y_center - h / 2) * height)
        x2 = int((x_center + w / 2) * width)
        y2 = int((y_center + h / 2) * height)
        cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
    return image

# %% [markdown]
# The function "print_random_images" takes in input the list of images' paths, a number defining how much images we want to print. So it randomly selects the images to display and calls "draw_yolo_bbox".

# %%
def print_random_imagesFireandSmoke(image_paths, n=30):
    selected_images = random.sample(image_paths, n)

    plt.figure(figsize=(15, 10))
    for i, img_path in enumerate(selected_images):
        # get file name (without extension)
        name = os.path.splitext(os.path.basename(img_path))[0]
        # construct label path correctly
        label_path = os.path.join(os.path.dirname(os.path.dirname(img_path)), "labels", f"{name}.txt")

        # draw boxes
        image = draw_yolo_bbox(img_path, label_path)
        plt.subplot(2, 3, i+1)
        plt.imshow(image)
        plt.axis("off")
        plt.title(name)
    plt.show()

# %%
def print_random_imagesHomeFire(image_paths, n=30):
    selected_images = random.sample(image_paths, n)

    plt.figure(figsize=(15, 10))
    for i, img_path in enumerate(selected_images):
        # get file name (without extension)
        name = os.path.splitext(os.path.basename(img_path))[0]
        # construct label path correctly
        label_path = os.path.join(os.path.dirname(os.path.dirname(img_path)), "labels", f"{name}.txt")

        # draw boxes
        image = draw_yolo_bbox(img_path, label_path)
        plt.subplot(2, 3, i+1)
        plt.imshow(image)
        plt.axis("off")
        plt.title(name)
    plt.show()

# %%
import os, random
from pathlib import Path
from PIL import Image, ImageDraw, ImageStat
import matplotlib.pyplot as plt

# ============================================================
# 1️⃣ CLASS LABELS (TEXT-ONLY)
# ============================================================
class_labels = {
    0: "Fire",
    1: "Serious Smoke",
    2: "Moderate Smoke",
    3: "Mild Smoke",
    4: "Steam / False Alarm",
    5: "Non-Fire Smoke",
    6: "Incense / Non-Threat Smoke"
}

# ============================================================
# 2️⃣ YOLO TXT → BBox
# ============================================================
def yolo_to_bbox(line, w, h):
    parts = line.strip().split()
    if len(parts) != 5:
        return None, None
    cid, xc, yc, bw, bh = map(float, parts)
    xc, yc, bw, bh = xc * w, yc * h, bw * w, bh * h
    return int(cid), (int(xc - bw / 2), int(yc - bh / 2), int(xc + bw / 2), int(yc + bh / 2))

# ============================================================
# 3️⃣ Condition Analyzer (Intensity + Visibility)
# ============================================================
def analyze_conditions(img, bbox, cid):
    x1, y1, x2, y2 = bbox
    region = img.crop((x1, y1, x2, y2)).convert("L")
    stat = ImageStat.Stat(region)
    mean_brightness = stat.mean[0] / 255
    stddev = stat.stddev[0] / 255

    # Visibility
    if stddev < 0.25:
        visibility = "Low Visibility"
    elif stddev < 0.45:
        visibility = "Partial Visibility"
    else:
        visibility = "Clear Details"

    # Intensity logic
    if cid == 0:  # Fire
        if mean_brightness > 0.75 and stddev > 0.5:
            label = f"Fire — High Intensity (Flames Visible, {visibility})"
        elif mean_brightness > 0.55:
            label = f"Fire — Medium Intensity (Active Burn, {visibility})"
        elif mean_brightness > 0.35:
            label = f"Fire — Moderate Intensity ({visibility})"
        else:
            label = f"Fire — Low Intensity (Smoldering, {visibility})"

    elif cid in [1, 2, 3, 5]:  # Smoke
        if mean_brightness < 0.25:
            label = f"Smoke — Dense (Toxic, {visibility})"
        elif mean_brightness < 0.45:
            label = f"Smoke — Moderate (Thick, {visibility})"
        else:
            label = f"Smoke — Light (Thin Haze, {visibility})"

    elif cid == 4:
        label = f"Steam — {'Bright' if mean_brightness > 0.6 else 'Dim'} ({visibility})"

    elif cid == 6:
        label = f"Incense — {'Gentle' if mean_brightness > 0.6 else 'Subtle'} ({visibility})"

    else:
        label = f"Unknown ({visibility})"

    return (255, 255, 255), label  # white outline, text-only


# ============================================================
# 5️⃣ Non-Repeating Trackers
# ============================================================
shown_FireSmoke = set()
shown_HomeFire_Test = set()
shown_Dataset1 = set()
shown_Dataset2 = set()

# ============================================================
# 6️⃣ Visualization Grid
# ============================================================
def show_random_images(image_dir, label_dir, shown_set, title, n=30):
    image_exts = (".jpg", ".jpeg", ".png")
    image_paths = [p for p in Path(image_dir).glob("*")
                   if p.suffix.lower() in image_exts and (Path(label_dir) / (p.stem + ".txt")).exists()]
    unseen = [p for p in image_paths if p.stem not in shown_set]

    if not unseen:
        print(f"✅ All {title} images have been shown. Resetting.")
        shown_set.clear()
        unseen = image_paths

    selected = random.sample(unseen, min(n, len(unseen)))
    shown_set.update(p.stem for p in selected)

    plt.figure(figsize=(15, 10))
    for i, img_path in enumerate(selected):
        label_path = Path(label_dir) / f"{img_path.stem}.txt"
        img = draw_yolo_bbox(img_path, label_path)
        plt.subplot(5, 6, i + 1)
        plt.imshow(img)
        plt.axis("off")
        plt.text(0.5, -0.15, img_path.stem, fontsize=9, ha="center", transform=plt.gca().transAxes)
    plt.suptitle(f"{title} — {len(selected)} Images", fontsize=14)
    plt.tight_layout()
    plt.show()

# ============================================================
# 7️⃣ RUN — All Datasets (Unified)
# ============================================================
show_random_images(
    "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/train2017",
    "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/labels/train",
    shown_FireSmoke, "Fire + Smoke Dataset", n=30)

show_random_images(
    "/content/drive/MyDrive/Home fire dataset/test/images",
    "/content/drive/MyDrive/Home fire dataset/test/labels",
    shown_HomeFire_Test, "Home Fire Test Dataset", n=30)

show_random_images(
    "/content/drive/MyDrive/dataset 1/images/train",
    "/content/drive/MyDrive/dataset 1/labels/train",
    shown_Dataset1, "Dataset 1 — Train", n=30)

show_random_images(
    "/content/drive/MyDrive/dataset 1/images/val",
    "/content/drive/MyDrive/dataset 1/labels/val",
    shown_Dataset1, "Dataset 1 — Val", n=30)

show_random_images(
    "/content/drive/MyDrive/dataset 2/images/train",
    "/content/drive/MyDrive/dataset 2/labels/train",
    shown_Dataset2, "Dataset 2 — Train", n=30)

show_random_images(
    "/content/drive/MyDrive/dataset 2/images/val",
    "/content/drive/MyDrive/dataset 2/labels/val",
    shown_Dataset2, "Dataset 2 — Val", n=30)

# %%
import os, re, random
from pathlib import Path
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# =========================
# Naming helpers (ONE place)
# =========================
ANNOT_SUFFIX = "_annotation"

def strip_annotation(stem: str) -> str:
    s = stem
    for suf in ("_annotation", "_annotated"):
        while s.lower().endswith(suf):
            s = s[: -len(suf)]
    return s

def with_annotation(stem: str) -> str:
    return f"{strip_annotation(stem)}{ANNOT_SUFFIX}"

def normalize_existing_names(root_dir: str):
    root = Path(root_dir)
    for p in root.rglob("*"):
        if not p.is_file():
            continue
        if p.suffix.lower() not in (".jpg", ".jpeg", ".png", ".txt"):
            continue
        new_stem = with_annotation(p.stem)
        if new_stem != p.stem:
            p.rename(p.with_name(new_stem + p.suffix))

# ============================================================
# 1️⃣ Class Labels & Colors (text-only)
# ============================================================
class_labels = {
    0: "Fire",
    1: "Serious Smoke",
    2: "Moderate Smoke",
    3: "Mild Smoke",
    4: "Steam / False Alarm",
    5: "Non-Fire Smoke",
    6: "Incense / Non-Threat Smoke"
}
base_colors = {
    0: (255, 60, 0),
    1: (80, 80, 80),
    2: (180, 100, 20),
    3: (255, 220, 50),
    4: (150, 150, 150),
    5: (200, 200, 200),
    6: (130, 200, 255)
}

# ============================================================
# Parsing utilities
# ============================================================
def _is_float(s: str) -> bool:
    try: float(s); return True
    except Exception: return False

def _conf_from_parts(parts, default_conf: float) -> float:
    for i in (5, 4):
        if len(parts) > i and _is_float(parts[i]):
            return float(parts[i])
    return default_conf

def parse_label_file(label_path, w, h, default_conf=None):
    """Read YOLO txt strictly; return only if real data exists."""
    items, norm_lines = [], []
    if not label_path or not os.path.exists(label_path):
        return items, norm_lines

    with open(label_path, "r") as f:
        lines = [ln.strip() for ln in f if ln.strip() and not ln.startswith("#")]

    if not lines:  # Empty file → skip
        return items, norm_lines

    for raw in lines:
        parts = raw.split()
        if len(parts) < 5 or not all(_is_float(p) for p in parts[:5]):
            continue

        cid = int(float(parts[0]))
        xc, yc, bw, bh = map(float, parts[1:5])
        conf = float(parts[5]) if len(parts) >= 6 and _is_float(parts[5]) else None

        norm_lines.append(
            f"{cid} {xc:.6f} {yc:.6f} {bw:.6f} {bh:.6f}" + (f" {conf:.2f}" if conf else "")
        )

        Xc, Yc, W, H = xc*w, yc*h, bw*w, bh*h
        x1, y1, x2, y2 = int(Xc-W/2), int(Yc-H/2), int(Xc+W/2), int(Yc+H/2)
        items.append((cid, (x1, y1, x2, y2), conf))

    return items, norm_lines



def yolo_to_bbox(line, w, h, default_conf=1.00):
    parts = line.strip().split()
    if len(parts) < 5: return None, None, None
    cid = int(float(parts[0])); xc, yc, bw, bh = map(float, parts[1:5])
    conf = _conf_from_parts(parts, default_conf)
    xc, yc, bw, bh = xc*w, yc*h, bw*w, bh*h
    bbox = (int(xc - bw/2), int(yc - bh/2), int(xc + bw/2), int(yc + bh/2))
    return cid, bbox, conf

# ============================================================
# 3️⃣ Pure Data-Based Function (no visualization)
# ============================================================
def draw_items_on_image(img_path, items):
    """
    PURE DATA MODE — no drawing, no colors, no visualization.
    Simply returns the bounding boxes from the .txt file data.
    """
    # Just open image to get size (if needed downstream)
    img = Image.open(img_path).convert("RGB")

    # Nothing drawn — return the raw image for pipeline continuity
    return img

# ============================================================
# 4️⃣ Label verification
# ============================================================
def ensure_label_files_exist(image_dir, label_dir):
    exts = (".jpg",".jpeg",".png")
    img_paths = [p for p in Path(image_dir).glob("*") if p.suffix.lower() in exts]
    label_dir = Path(label_dir); label_dir.mkdir(parents=True, exist_ok=True)
    created = []
    for img_path in img_paths:
        label_path = label_dir / f"{img_path.stem}.txt"
        if not label_path.exists():
            label_path.write_text("")
            created.append(label_path.name)
    print(f"✅ Verified: {len(img_paths)} images | 🆕 Created: {len(created)} empty label files")

# ============================================================
# 5️⃣ Export normalized labels ( *_annotation.txt )
# ============================================================
def export_all_labels(image_dir, label_dir, export_dir, default_conf=1.00):
    image_dir, label_dir, export_dir = map(Path, (image_dir, label_dir, export_dir))
    export_dir.mkdir(parents=True, exist_ok=True)
    exts = (".jpg",".jpeg",".png")
    imgs = [p for p in image_dir.rglob("*") if p.suffix.lower() in image_exts and "_annotation" not in p.stem]
    saved = blanks = 0
    for img in imgs:
        lbl = label_dir / f"{img.stem}.txt"
        w,h = Image.open(img).size
        _, norm_lines = parse_label_file(lbl, w, h, default_conf)
        out = export_dir / f"{with_annotation(img.stem)}.txt"
        if norm_lines:
            out.write_text("\n".join(norm_lines)+"\n"); saved += 1
        else:
            out.write_text(""); blanks += 1
    print(f"📝 Exported {saved} with data | ⚪ {blanks} empty to {export_dir}")

# ============================================================
# 6️⃣ Display and save annotated previews
# ============================================================
def display_and_save_random_images(image_dir, label_dir, shown_set, title, save_subdir, n=20, default_conf=1.00):
    save_root = Path("/content/drive/MyDrive/fire_smoke_previews")
    save_dir = save_root / save_subdir
    save_dir.mkdir(parents=True, exist_ok=True)
    exts = (".jpg",".jpeg",".png")
    image_paths = [p for p in Path(image_dir).glob("*") if p.suffix.lower() in exts and "_annotation" not in p.stem]
    if not image_paths:
        print(f"🚫 No images found in {image_dir}"); return
    unseen = [p for p in image_paths if p.stem not in shown_set] or image_paths
    selected = random.sample(unseen, min(n, len(unseen)))
    shown_set.update(p.stem for p in selected)

    print(f"\n📸 Annotating {len(selected)} samples from {title}")
    for img_path in selected:
        lbl = Path(label_dir) / f"{img_path.stem}.txt"
        w,h = Image.open(img_path).size
        items, norm_lines = parse_label_file(lbl, w, h, default_conf)
        img = draw_items_on_image(img_path, items)
        out_path = save_dir / f"{with_annotation(img_path.stem)}.jpg"
        img.save(out_path)
        if norm_lines:
            (save_dir / f"{with_annotation(img_path.stem)}.txt").write_text("\n".join(norm_lines)+"\n")
        # Skip visualization completely — only save .txt data
        continue

    print(f"✅ Done saving annotated images to {save_dir}")

# ============================================================
# 7️⃣ Main pipeline for Dataset 1 & 2
# ============================================================
# Normalize any *_annotated names
normalize_existing_names("/content/drive/MyDrive/fire_smoke_previews/dataset1_output")
normalize_existing_names("/content/drive/MyDrive/fire_smoke_previews/dataset2_output")

# Ensure label placeholders exist
for d in [
    ("/content/drive/MyDrive/dataset 1/images/train", "/content/drive/MyDrive/dataset 1/labels/train"),
    ("/content/drive/MyDrive/dataset 1/images/val", "/content/drive/MyDrive/dataset 1/labels/val"),
    ("/content/drive/MyDrive/dataset 2/images/train", "/content/drive/MyDrive/dataset 2/labels/train"),
    ("/content/drive/MyDrive/dataset 2/images/val", "/content/drive/MyDrive/dataset 2/labels/val"),
]:
    ensure_label_files_exist(*d)

# Export normalized YOLO labels
export_all_labels(
    "/content/drive/MyDrive/dataset 1/images/train",
    "/content/drive/MyDrive/dataset 1/labels/train",
    "/content/drive/MyDrive/fire_smoke_previews/dataset1_output/train")
export_all_labels(
    "/content/drive/MyDrive/dataset 1/images/val",
    "/content/drive/MyDrive/dataset 1/labels/val",
    "/content/drive/MyDrive/fire_smoke_previews/dataset1_output/val")
export_all_labels(
    "/content/drive/MyDrive/dataset 2/images/train",
    "/content/drive/MyDrive/dataset 2/labels/train",
    "/content/drive/MyDrive/fire_smoke_previews/dataset2_output/train")
export_all_labels(
    "/content/drive/MyDrive/dataset 2/images/val",
    "/content/drive/MyDrive/dataset 2/labels/val",
    "/content/drive/MyDrive/fire_smoke_previews/dataset2_output/val")

# Visualize samples
shown_Dataset1, shown_Dataset2 = set(), set()
display_and_save_random_images(
    "/content/drive/MyDrive/dataset 1/images/train",
    "/content/drive/MyDrive/dataset 1/labels/train",
    shown_Dataset1, "Dataset 1 Train", "dataset1_output/train")
display_and_save_random_images(
    "/content/drive/MyDrive/dataset 1/images/val",
    "/content/drive/MyDrive/dataset 1/labels/val",
    shown_Dataset1, "Dataset 1 Val", "dataset1_output/val")
display_and_save_random_images(
    "/content/drive/MyDrive/dataset 2/images/train",
    "/content/drive/MyDrive/dataset 2/labels/train",
    shown_Dataset2, "Dataset 2 Train", "dataset2_output/train")
display_and_save_random_images(
    "/content/drive/MyDrive/dataset 2/images/val",
    "/content/drive/MyDrive/dataset 2/labels/val",
    shown_Dataset2, "Dataset 2 Val", "dataset2_output/val")

# %%
from pathlib import Path

def remove_empty_or_non_numeric_txt(dirpath):
    p = Path(dirpath)
    removed = 0
    for f in p.glob("*.txt"):
        txt = f.read_text().strip()
        has_numeric = any(ln and ln[0].isdigit() for ln in txt.splitlines())
        if (not txt) or (not has_numeric):
            f.unlink()
            removed += 1
    print(f"🧹 Removed {removed} empty/invalid txt files from {dirpath}")

remove_empty_or_non_numeric_txt("/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output")
remove_empty_or_non_numeric_txt("/content/drive/MyDrive/fire_smoke_previews/home_fire_output")

# %%
import os
label_dir = "/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output/labels"
print("Number of TXT label files:", sum(1 for f in os.listdir(label_dir) if f.endswith(".txt")))
print("Sample label filenames:")
for f in sorted(os.listdir(label_dir))[:10]:
    print(" -", f)

# %% [markdown]
# Now, finally calling the function to display 30 images randomly.

# %%
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import math

ANNOTATED_SUFFIXES = ("_annotated", "_annotation")
IMG_EXTS = (".jpg", ".jpeg", ".png")

def display_all_annotated_images(title, root_dir, per_page=30, cols=6, recursive=True):
    """
    Show ALL annotated images in `root_dir`, paged `per_page` at a time.
    Looks for files whose stem ends with _annotated or _annotation.
    """
    root = Path(root_dir)
    it = root.rglob("*") if recursive else root.glob("*")
    imgs = sorted(
        [p for p in it if p.suffix.lower() in IMG_EXTS
         and p.stem.endswith(ANNOTATED_SUFFIXES)]
    )

    if not imgs:
        print(f"⚠️ No annotated images found in {root_dir} (expected *{ANNOTATED_SUFFIXES}.[jpg|png]).")
        return

    print(f"📷 {title}: showing {len(imgs)} annotated images from {root_dir}")

    for i in range(0, len(imgs), per_page):
        batch = imgs[i:i+per_page]
        rows = math.ceil(len(batch) / cols)
        plt.figure(figsize=(3.2*cols, 3.2*rows))
        for j, p in enumerate(batch, 1):
            plt.subplot(rows, cols, j)
            plt.imshow(Image.open(p))
            plt.title(p.name, fontsize=8)
            plt.axis("off")
        plt.suptitle(f"{title} — {i+1}–{i+len(batch)} of {len(imgs)}", fontsize=12)
        plt.tight_layout()
        plt.show()

# %%
display_all_annotated_images("🔥 Fire + Smoke (annotated)",
    "/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output")

display_all_annotated_images("🏠 Home Fire Test (annotated)",
    "/content/drive/MyDrive/fire_smoke_previews/home_fire_output")

# %% [markdown]
# ## Dataset Cleaning

# %% [markdown]
# Interestingly, we found out that this dataset is not clean. i.e. labels of some of the images are missing and there are extra labels. So, we need to find out the missing labels files and remove that from the labels folder. Also, we need to find out missing images, which we also need to remove from the images folder.

# %%
#we already have a list of images' paths and labels' path, stored in variables : image_paths and label_paths
print(image_paths)
print(label_paths)

# %% [markdown]
# Now, we make a list of only the names of images' files and labels' files.
#
# e.g.  only  000000000531 without the extension

# %%
# Get the list of filenames without extensions
image_files = {file.split("/")[-1].split(".")[0] for file in image_paths}
label_files = {file.split("/")[-1].split(".")[0] for file in label_paths}

print(image_files)

# %%
# Find extra files in each folder
extra_images = image_files - label_files
extra_labels = label_files - image_files

# Output the results
print(f"Extra images (without corresponding labels): {extra_images}")
print(f"Extra labels (without corresponding images): {extra_labels}")

# %%
import os

# Corrected removal loop
for file in extra_images:
    # Get only the filename without any folder
    filename = os.path.basename(file)
    image_path = os.path.join(dataset_path, "images", filename)
    if os.path.exists(image_path):
        os.remove(image_path)
        print(f"Removed: {image_path}")
    else:
        print(f"Not found: {image_path}")

for file in extra_labels:
    filename = os.path.basename(file)
    label_path = os.path.join(dataset_path, "labels", filename)
    if os.path.exists(label_path):
        os.remove(label_path)
        print(f"Removed: {label_path}")
    else:
        print(f"Not found: {label_path}")

# %% [markdown]
# Now removing them from the dataset:

# %% [markdown]
# Check again if it worked:

# %%
# Get the list of all images paths in the dataset
image_paths = [os.path.join(dataset_path, "images", image_name) for image_name in os.listdir(os.path.join(dataset_path, "images"))]

# Get the list of all labels paths in the dataset
label_paths = [os.path.join(dataset_path, "labels", label_name) for label_name in os.listdir(os.path.join(dataset_path, "labels"))]

# Get the list of filenames without extensions
image_files = {file.split("/")[-1].split(".")[0] for file in image_paths}
label_files = {file.split("/")[-1].split(".")[0] for file in label_paths}
# Find extra files in each folder
extra_images = image_files - label_files
extra_labels = label_files - image_files

# Output the results
print(f"Extra images (without corresponding labels): {extra_images}")
print(f"Extra labels (without corresponding images): {extra_labels}")

# %% [markdown]
# There are none! great!

# %%
# !pip install ultralytics
# !pip install numpy torch torchvision

# %%
# ✅ YOLOv8 Fire/Smoke CPU-Stable Trainer (v7.4 — Using fire_and_smoke_output folders)
import os, sys, yaml, glob, subprocess, importlib, torch, multiprocessing
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# ============================================================
# 1️⃣  Force NumPy
# ============================================================
def force_numpy():
    try:
        import numpy as np
        _ = np.zeros((1, 1))
        print("✅ NumPy working fine.")
    except Exception as e:
        print(f"⚠️ NumPy issue: {e} — reinstalling…")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "--force-reinstall", "numpy"])
        import numpy as np
    globals()["np"] = importlib.import_module("numpy")
    return globals()["np"]

np = force_numpy()

# ============================================================
# 2️⃣ Dataset Paths (updated)
# ============================================================
train_images = "/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output/images"
train_labels = "/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output/labels"
val_images   = "/content/drive/MyDrive/fire_smoke_previews/home_fire_output/images"
val_labels   = "/content/drive/MyDrive/fire_smoke_previews/home_fire_output/labels"
yaml_path    = "/content/drive/MyDrive/fire_smoke/data.yaml"

# ============================================================
# 3️⃣ Check images + labels
# ============================================================
def check_images_labels(image_dir):
    img_exts = (".jpg", ".jpeg", ".png")
    imgs = [f for ext in img_exts for f in glob.glob(os.path.join(image_dir, f"*{ext}"))]
    lbls = [f for f in glob.glob(os.path.join(image_dir, "*.txt"))]
    print(f"✅ Found {len(imgs)} images and {len(lbls)} labels in {os.path.basename(image_dir)}")
    return imgs, lbls

train_imgs, train_lbls = check_images_labels(train_images)
val_imgs, val_lbls = check_images_labels(val_images)

if len(train_lbls) == 0:
    print("🚨 WARNING: No training labels found. Ensure your .txt annotations exist in:")
    print(train_labels)

# ============================================================
# 4️⃣ YAML File (using the new output folders)
# ============================================================
os.makedirs(os.path.dirname(yaml_path), exist_ok=True)
yaml.safe_dump({
    "train": train_images,
    "val": val_images,
    "names": [
        "Fire",
        "Serious Smoke",
        "Moderate Smoke",
        "Mild Smoke",
        "Steam / False Alarm",
        "Non-Fire Smoke",
        "Incense / Non-Threat Smoke"
    ],
    "nc": 7
}, open(yaml_path, "w"))
print(f"✅ Dataset YAML created → {yaml_path}")

# ============================================================
# 5️⃣ System Info
# ============================================================
import ultralytics
print(f"\n🔎 YOLOv8 version: {ultralytics.__version__}")
if torch.cuda.is_available():
    print(f"✅ CUDA: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ Running on CPU only.")

# ============================================================
# 6️⃣ Training
# ============================================================
multiprocessing.set_start_method("spawn", force=True)
model = YOLO("yolov8n.pt")

train_args = dict(
    data=yaml_path,
    epochs=50,
    imgsz=416,
    batch=4,
    workers=0,
    freeze=0,
    patience=5,
    lr0=0.005,
    weight_decay=0.0005,
    exist_ok=True,
    name="fire_smoke_yolov8n_cpu_stable_v74"
)

print("\n🚀 Starting YOLOv8 training using fire_and_smoke_output + home_fire_output dataset…\n")
results = model.train(**train_args)
print("\n✅ Training completed successfully (v7.4).")

# ============================================================
# 7️⃣ Annotated Predictions — Save Back to the Same Folders (Fixed)
# ============================================================
import shutil

print("\n🎨 Generating annotated predictions and saving into the same folders…")

for img_dir, label in [
    ("/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output", "TRAIN"),
    ("/content/drive/MyDrive/fire_smoke_previews/home_fire_output", "VAL")
]:
    sample_imgs = glob.glob(os.path.join(img_dir, "*.jpg"))
    for img_path in sample_imgs:
        results = model.predict(source=img_path, save=True, save_txt=True, conf=0.15)
        annotated_path = Path(results[0].save_dir) / os.path.basename(img_path)
        new_path = os.path.join(
            img_dir,
            f"{os.path.splitext(os.path.basename(img_path))[0]}_annotated.jpg"
        )

        if os.path.exists(annotated_path):
            try:
                shutil.move(str(annotated_path), new_path)  # ✅ works across drives
                print(f"✅ Saved {label} annotated image → {new_path}")
            except Exception as e:
                print(f"⚠️ Could not move {annotated_path}: {e}")
        else:
            print(f"⚠️ No detection result for: {img_path}")



# ============================================================
# 8️⃣ Display Preview Inline
# ============================================================
preview_samples = glob.glob(os.path.join(train_images, "*_annotated.jpg"))[:3] + \
                  glob.glob(os.path.join(val_images, "*_annotated.jpg"))[:3]

if preview_samples:
    plt.figure(figsize=(15, 10))
    for i, path in enumerate(preview_samples):
        img = Image.open(path)
        plt.subplot(2, 3, i + 1)
        plt.imshow(img)
        plt.axis("off")
        plt.title(os.path.basename(path))
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ No annotated preview images found.")

print(f"\n🎉 All annotated predictions saved into:\n🔥 {train_images}\n🏠 {val_images}")

# %%
# !ls "/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output/labels" | head

# %%
# ============================================================
# 🚀 YOLOv8 Fire/Smoke Full Training + Evaluation Pipeline (v8.1 FIXED)
# Compatible with Ultralytics v8.3.x (no plot_confusion_matrix)
# ============================================================

import os, sys, glob, yaml, subprocess, importlib, torch, shutil, random, multiprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, precision_recall_curve, average_precision_score
from ultralytics import YOLO
from pathlib import Path
from PIL import Image

# ============================================================
# 1️⃣  Force NumPy
# ============================================================
def force_numpy():
    try:
        import numpy as np
        _ = np.zeros((1, 1))
        print("✅ NumPy loaded successfully.")
    except Exception as e:
        print(f"⚠️ NumPy issue: {e} — reinstalling…")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "--force-reinstall", "numpy"])
        import numpy as np
    globals()["np"] = importlib.import_module("numpy")
    return globals()["np"]

np = force_numpy()

import ultralytics
print(f"🔍 YOLOv8 version: {ultralytics.__version__}")
print(f"💻 Torch CUDA available: {torch.cuda.is_available()}")

# ============================================================
# 2️⃣ Dataset Paths
# ============================================================
train_images = "/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output"
val_images   = "/content/drive/MyDrive/fire_smoke_previews/home_fire_output"
yaml_path    = "/content/drive/MyDrive/fire_smoke/data.yaml"

# ============================================================
# 3️⃣ Verify Images & Labels
# ============================================================
def check_images_labels(image_dir):
    img_exts = (".jpg", ".jpeg", ".png")
    imgs = [f for ext in img_exts for f in glob.glob(os.path.join(image_dir, f"*{ext}"))]
    lbls = [f for f in glob.glob(os.path.join(image_dir, "*.txt"))]
    print(f"📁 {os.path.basename(image_dir)} → {len(imgs)} images, {len(lbls)} labels")
    return imgs, lbls

train_imgs, train_lbls = check_images_labels(train_images)
val_imgs, val_lbls = check_images_labels(val_images)

# ============================================================
# 4️⃣ Create YAML Config
# ============================================================
os.makedirs(os.path.dirname(yaml_path), exist_ok=True)
yaml.safe_dump({
    "train": train_images,
    "val": val_images,
    "nc": 7,
    "names": [
        "Fire",
        "Serious Smoke",
        "Moderate Smoke",
        "Mild Smoke",
        "Steam / False Alarm",
        "Non-Fire Smoke",
        "Incense / Non-Threat Smoke"
    ]
}, open(yaml_path, "w"))
print(f"✅ YAML written → {yaml_path}")

# ============================================================
# 5️⃣ Train Model
# ============================================================
model = YOLO("yolov8n.pt")
multiprocessing.set_start_method("spawn", force=True)

train_args = dict(
    data=yaml_path,
    epochs=50,
    imgsz=416,
    batch=4,
    workers=0,
    freeze=10,
    patience=5,
    lr0=0.005,
    weight_decay=0.0005,
    name="fire_smoke_yolov8n_v8full",
    exist_ok=True
)

print("\n🚀 Starting training...\n")
results = model.train(**train_args)
print("\n✅ Training complete!\n")

# ============================================================
# 6️⃣ Evaluate and Compute Metrics
# ============================================================
print("📊 Evaluating model...")
metrics = model.val(data=yaml_path, split="val")

print("\n🧮 Evaluation summary:")
try:
    p = float(metrics.box.p.mean()) if hasattr(metrics.box.p, "mean") else float(metrics.box.p)
    r = float(metrics.box.r.mean()) if hasattr(metrics.box.r, "mean") else float(metrics.box.r)
    map50 = float(metrics.box.map50.mean()) if hasattr(metrics.box.map50, "mean") else float(metrics.box.map50)
    map95 = float(metrics.box.map.mean()) if hasattr(metrics.box.map, "mean") else float(metrics.box.map)
    print(f"Precision: {p:.3f}")
    print(f"Recall:    {r:.3f}")
    print(f"mAP50:     {map50:.3f}")
    print(f"mAP50-95:  {map95:.3f}")
except Exception as e:
    print("⚠️ Could not summarize metrics:", e)
    print(metrics)

# ============================================================
# 7️⃣ Confusion Matrix (Manual, Compatible with v8.3.x)
# ============================================================
print("\n🎯 Generating confusion matrix...")

try:
    true_classes = np.concatenate(metrics.box.tcls)
    pred_classes = np.concatenate(metrics.box.pred_cls)
    class_names = list(metrics.names.values())

    if len(true_classes) > 0 and len(pred_classes) > 0:
        cm = confusion_matrix(true_classes, pred_classes, normalize="true")
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues",
                    xticklabels=class_names, yticklabels=class_names)
        plt.title("🔥 Fire & Smoke Detection — Normalized Confusion Matrix")
        plt.xlabel("Predicted Class")
        plt.ylabel("True Class")
        plt.tight_layout()
        plt.savefig("/content/confusion_matrix.png")
        plt.show()
        print("✅ Confusion matrix saved → /content/confusion_matrix.png")
    else:
        print("⚠️ Not enough data to generate confusion matrix.")
except Exception as e:
    print("⚠️ Error while generating confusion matrix:", e)

# ============================================================
# 8️⃣ Precision-Recall Curve (Manual)
# ============================================================
print("\n📈 Generating Precision-Recall curve...")
try:
    y_true = np.concatenate(metrics.box.tcls)
    y_conf = np.concatenate(metrics.box.conf)
    precision, recall, _ = precision_recall_curve(y_true, y_conf)
    ap = average_precision_score(y_true, y_conf)

    plt.figure(figsize=(7, 5))
    plt.plot(recall, precision, color="purple", lw=2, label=f"AP = {ap:.3f}")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("Precision-Recall Curve")
    plt.legend()
    plt.grid(True)
    plt.savefig("/content/precision_recall_curve.png")
    plt.show()
    print("✅ PR curve saved → /content/precision_recall_curve.png")
except Exception as e:
    print("⚠️ Could not compute PR curve:", e)

# ============================================================
# 9️⃣ Annotated Predictions
# ============================================================
print("\n🎨 Generating annotated predictions...")
for img_dir, label in [
    (train_images, "TRAIN"),
    (val_images, "VAL")
]:
    sample_imgs = glob.glob(os.path.join(img_dir, "*.jpg"))
    for img_path in sample_imgs:
        results = model.predict(source=img_path, save=True, save_txt=False, conf=0.3)
        annotated_path = Path(results[0].save_dir) / os.path.basename(img_path)
        new_path = os.path.join(
            img_dir,
            f"{os.path.splitext(os.path.basename(img_path))[0]}_annotated.jpg"
        )
        try:
            shutil.move(str(annotated_path), new_path)
            print(f"✅ Saved {label} annotated image → {new_path}")
        except Exception as e:
            print(f"⚠️ Could not move {annotated_path}: {e}")

# ============================================================
# 🔟 Display 30 Annotated Samples
# ============================================================
def display_random_annotated_images(img_dir, title, n=30):
    annotated_imgs = glob.glob(os.path.join(img_dir, "*_annotated.jpg"))
    if not annotated_imgs:
        print(f"⚠️ No annotated images found in {img_dir}")
        return
    sample_imgs = random.sample(annotated_imgs, min(n, len(annotated_imgs)))
    plt.figure(figsize=(15, 15))
    for i, path in enumerate(sample_imgs[:30]):
        img = Image.open(path)
        plt.subplot(6, 5, i + 1)
        plt.imshow(img)
        plt.axis("off")
        plt.title(os.path.basename(path), fontsize=8)
    plt.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()

display_random_annotated_images(train_images, "🔥 Fire + Smoke Dataset (30 Samples)")
display_random_annotated_images(val_images, "🏠 Home Fire Dataset (30 Samples)")

print("\n🎉 All steps completed successfully!")

# %%
import glob

train_files = glob.glob("/content/drive/MyDrive/fire_smoke_previews/fire_and_smoke_output/*_annotated*.jpg")
val_files = glob.glob("/content/drive/MyDrive/fire_smoke_previews/home_fire_output/*_annotated*.jpg")

print(f"TRAIN annotated images saved: {len(train_files)}")
print(f"VAL annotated images saved:   {len(val_files)}")
print(f"Total annotated files:         {len(train_files) + len(val_files)}")

# %%
# ============================================================
# 9️⃣ Evaluate model and visualize confusion matrix
# ============================================================
from ultralytics.utils import ops
from ultralytics.utils.plotting import plot_results
from ultralytics.utils.metrics import ConfusionMatrix
import numpy as np
import matplotlib.pyplot as plt

print("\n📊 Evaluating trained model and generating confusion matrix...")

# Load best model from training
model_path = "/content/runs/detect/fire_smoke_yolov8n_cpu_stable_v74/weights/best.pt"
model = YOLO(model_path)

# Run validation to get metrics and confusion matrix data
metrics = model.val(conf=0.25, imgsz=416)

# Compute and display confusion matrix
cm = metrics.confusion_matrix.matrix  # numpy array (num_classes x num_classes)

plt.figure(figsize=(8, 6))
plt.imshow(cm, cmap="Blues")
plt.title("🔥 Fire & Smoke Detection Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.colorbar()
plt.show()

# Print summarized results
print("\n🧮 Evaluation Summary:")
try:
    p = float(np.mean(metrics.box.p))
    r = float(np.mean(metrics.box.r))
    map50 = float(np.mean(metrics.box.map50))
    map95 = float(np.mean(metrics.box.map))
    print(f"Precision: {p:.3f}")
    print(f"Recall:    {r:.3f}")
    print(f"mAP50:     {map50:.3f}")
    print(f"mAP50-95:  {map95:.3f}")
except Exception as e:
    print("⚠️ Could not summarize metrics:", e)
    print(metrics)

# %%
# ------------------------------ imports ------------------------------
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt

print("\n📊 Evaluating trained model and generating confusion matrix...")

# ------------------------------ load & validate ------------------------------
model_path = "/content/runs/detect/fire_smoke_yolov8n_cpu_stable_v74/weights/best.pt"
model = YOLO(model_path)

# run validation
res = model.val(conf=0.25, imgsz=416, verbose=False)   # uses your data.yaml 'val'

# ------------------------------ confusion matrix ------------------------------
cm_obj = getattr(res, "confusion_matrix", None)
if cm_obj is None or getattr(cm_obj, "matrix", None) is None:
    raise RuntimeError("No confusion matrix found in results. Check that your val set has valid labels.")

cm = cm_obj.matrix.astype(float)
names = getattr(model, "names", None)
if names is None and hasattr(model, "model"):
    names = getattr(model.model, "names", {})
names = names or {}
n = cm.shape[0]
tick_labels = [names.get(i, str(i)) for i in range(n)]

fig, ax = plt.subplots(figsize=(9, 7))
im = ax.imshow(cm, cmap="Blues", interpolation="nearest")

# Add colorbar
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel("Count", rotation=-90, va="bottom")

# Add tick labels
ax.set_xticks(range(n))
ax.set_yticks(range(n))
ax.set_xticklabels(tick_labels, rotation=45, ha="right")
ax.set_yticklabels(tick_labels)
ax.set_xlabel("Predicted Label")
ax.set_ylabel("True Label")
ax.set_title("🔥 Fire & Smoke Detection Confusion Matrix (Raw Counts)")

# Add numbers inside each square
for i in range(n):
    for j in range(n):
        val = cm[i, j]
        ax.text(j, i, f"{int(val)}", ha="center", va="center",
                color="black" if val < cm.max() / 2 else "white", fontsize=8)

plt.figtext(0.5, -0.05, "RAVDESS", ha="center", fontsize=10)
plt.tight_layout()
plt.show()

# ------------------------------ metrics (version-proof) ------------------------------
d = getattr(res, "results_dict", {})  # new API
def pick(keys, default=np.nan):
    for k in keys:
        if k in d:
            return float(d[k])
    return default

p     = pick(["metrics/precision(B)", "metrics/precision"])
r     = pick(["metrics/recall(B)", "metrics/recall"])
map50 = pick(["metrics/mAP50(B)", "metrics/mAP50"])
map95 = pick(["metrics/mAP50-95(B)", "metrics/mAP50-95"])

# fallback for older API
if np.isnan(p) and hasattr(res, "box"):
    p     = float(np.mean(res.box.p))
    r     = float(np.mean(res.box.r))
    map50 = float(np.mean(res.box.map50))
    map95 = float(np.mean(res.box.map))

print("\n🧮 Evaluation Summary:")
print(f"Precision: {p:.3f}")
print(f"Recall:    {r:.3f}")
print(f"mAP50:     {map50:.3f}")
print(f"mAP50-95:  {map95:.3f}")

# %%
from collections import Counter
import os

label_dir = "/content/drive/MyDrive/Fire and Smoke BBox COCO Dateset/coco128/labels/train2017"
counts = Counter()

for file in os.listdir(label_dir):
    if file.endswith(".txt"):
        for line in open(os.path.join(label_dir, file)):
            if line.strip():
                cid = int(line.split()[0])
                counts[cid] += 1

print("Class distribution:", counts)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(9,8))
sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues", xticklabels=tick_labels, yticklabels=tick_labels)
plt.title("🔥 Fire & Smoke Detection Confusion Matrix (Raw Counts)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.figtext(0.5, -0.05, "RAVDESS", ha="center", fontsize=10)
plt.tight_layout()
plt.show()

# %%
from pathlib import Path
lbl_dir = Path("/path/to/your/labels/val")  # point to your val labels folder
counts = {}
for f in lbl_dir.rglob("*.txt"):
    for ln in f.read_text().splitlines():
        if ln.strip() and ln.strip()[0].isdigit():
            c = int(float(ln.split()[0]))
            counts[c] = counts.get(c, 0) + 1
print("Val label counts per class-id:", counts)

# %%
print("\n📈 Plotting training and validation curves...")
plot_results("/content/runs/detect/fire_smoke_yolov8n_cpu_stable_v74/results.csv")

# %%
# ============================================================
# 🔍 Test on New Images/Videos
# ============================================================
test_source = "/content/drive/MyDrive/fire_smoke_previews/new_test_data"  # 🔁 your folder
os.makedirs(test_source, exist_ok=True)

print("\n🎥 Testing model on new data...")
results = model.predict(source=test_source, conf=0.3, save=True, save_txt=True)

print("✅ Predictions complete. Check annotated results in /runs/detect/predict/")

# %% [markdown]
# after training, all of the precision confusion matrix and everything, check to see if results are satisfactory
